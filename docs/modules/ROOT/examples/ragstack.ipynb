# %% [markdown]
# # RAGStack and Astra vector db
#
# This notebook demonstrates a RAG pattern using RAGStack and the AstraDB vector database.
#
# The pattern is:
#
# 1. Construct information base
# 2. Basic retrieval
# 3. Generation with augmented context
# 4. Advanced retrieval and generation
# 5. Evaluate quality

# %% [markdown]
# ## Setup
# RAGStack includes all the libraries you need for the RAG pattern, including the vector database, embeddings pipeline, and retrieval.

# %%
# !pip3 install ragstack-ai datasets
# Out:
# Requirement already satisfied: ragstack-ai in /opt/homebrew/lib/python3.11/site-packages (0.1.0)
# Requirement already satisfied: datasets in /opt/homebrew/lib/python3.11/site-packages (2.14.7)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (3.8.6)
# Requirement already satisfied: anyio<4.0 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (3.7.1)
# Requirement already satisfied: astrapy==0.5.8 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (0.5.8)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (0.6.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (1.33)
# Requirement already satisfied: numpy<2,>=1 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (1.26.2)
# Requirement already satisfied: openai<1,>=0 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (2.5.1)
# Requirement already satisfied: pytest-subtests<0.12.0,>=0.11.0 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (0.11.0)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (8.2.3)
# Requirement already satisfied: tiktoken<0.6.0,>=0.3.2 in /opt/homebrew/lib/python3.11/site-packages (from ragstack-ai) (0.5.1)
# Requirement already satisfied: faker~=19.11.0 in /opt/homebrew/lib/python3.11/site-packages (from astrapy==0.5.8->ragstack-ai) (19.11.1)
# Requirement already satisfied: pytest~=7.4.2 in /opt/homebrew/lib/python3.11/site-packages (from astrapy==0.5.8->ragstack-ai) (7.4.3)
# Requirement already satisfied: pytest-cov~=4.1.0 in /opt/homebrew/lib/python3.11/site-packages (from astrapy==0.5.8->ragstack-ai) (4.1.0)
# Requirement already satisfied: pytest-testdox~=3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from astrapy==0.5.8->ragstack-ai) (3.1.0)
# Requirement already satisfied: requests-toolbelt~=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from astrapy==0.5.8->ragstack-ai) (1.0.0)
# Requirement already satisfied: python-dotenv~=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from astrapy==0.5.8->ragstack-ai) (1.0.0)
# Requirement already satisfied: pre-commit~=3.5.0 in /opt/homebrew/lib/python3.11/site-packages (from astrapy==0.5.8->ragstack-ai) (3.5.0)
# Requirement already satisfied: cassio~=0.1.3 in /opt/homebrew/lib/python3.11/site-packages (from astrapy==0.5.8->ragstack-ai) (0.1.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/homebrew/lib/python3.11/site-packages (from datasets) (14.0.1)
# Requirement already satisfied: pyarrow-hotfix in /opt/homebrew/lib/python3.11/site-packages (from datasets) (0.5)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (from datasets) (2.1.3)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/homebrew/lib/python3.11/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /opt/homebrew/lib/python3.11/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/homebrew/lib/python3.11/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /opt/homebrew/lib/python3.11/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /opt/homebrew/lib/python3.11/site-packages (from datasets) (0.19.3)
# Requirement already satisfied: packaging in /Users/mendon.kissling/Library/Python/3.11/lib/python/site-packages (from datasets) (23.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->ragstack-ai) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->ragstack-ai) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->ragstack-ai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->ragstack-ai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->ragstack-ai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->ragstack-ai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->ragstack-ai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/lib/python3.11/site-packages (from anyio<4.0->ragstack-ai) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/lib/python3.11/site-packages (from anyio<4.0->ragstack-ai) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->ragstack-ai) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->ragstack-ai) (0.9.0)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.8.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->ragstack-ai) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3,>=1->ragstack-ai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.3 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3,>=1->ragstack-ai) (2.14.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->ragstack-ai) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->ragstack-ai) (2023.7.22)
# Requirement already satisfied: regex>=2022.1.18 in /opt/homebrew/lib/python3.11/site-packages (from tiktoken<0.6.0,>=0.3.2->ragstack-ai) (2023.10.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mendon.kissling/Library/Python/3.11/lib/python/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: cassandra-driver>=3.28.0 in /opt/homebrew/lib/python3.11/site-packages (from cassio~=0.1.3->astrapy==0.5.8->ragstack-ai) (3.28.0)
# Requirement already satisfied: cfgv>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai) (2.5.31)
# Requirement already satisfied: nodeenv>=0.11.1 in /opt/homebrew/lib/python3.11/site-packages (from pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai) (1.8.0)
# Requirement already satisfied: virtualenv>=20.10.0 in /opt/homebrew/lib/python3.11/site-packages (from pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai) (20.24.6)
# Requirement already satisfied: iniconfig in /opt/homebrew/lib/python3.11/site-packages (from pytest~=7.4.2->astrapy==0.5.8->ragstack-ai) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/homebrew/lib/python3.11/site-packages (from pytest~=7.4.2->astrapy==0.5.8->ragstack-ai) (1.3.0)
# Requirement already satisfied: coverage>=5.2.1 in /opt/homebrew/lib/python3.11/site-packages (from coverage[toml]>=5.2.1->pytest-cov~=4.1.0->astrapy==0.5.8->ragstack-ai) (7.3.2)
# Requirement already satisfied: six>=1.5 in /Users/mendon.kissling/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->ragstack-ai) (1.0.0)
# Requirement already satisfied: geomet<0.3,>=0.1 in /opt/homebrew/lib/python3.11/site-packages (from cassandra-driver>=3.28.0->cassio~=0.1.3->astrapy==0.5.8->ragstack-ai) (0.2.1.post1)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.11/site-packages (from nodeenv>=0.11.1->pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai) (68.2.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in /opt/homebrew/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai) (0.3.7)
# Requirement already satisfied: platformdirs<4,>=3.9.1 in /opt/homebrew/lib/python3.11/site-packages (from virtualenv>=20.10.0->pre-commit~=3.5.0->astrapy==0.5.8->ragstack-ai) (3.11.0)
# Requirement already satisfied: click in /opt/homebrew/lib/python3.11/site-packages (from geomet<0.3,>=0.1->cassandra-driver>=3.28.0->cassio~=0.1.3->astrapy==0.5.8->ragstack-ai) (8.1.7)

# %% [markdown]
# Import the necessary dependencies:

# %%
import getpass
from datasets import load_dataset
from langchain.vectorstores.astradb import AstraDB 
from langchain.embeddings import OpenAIEmbeddings
from langchain.schema import Document

# %% [markdown]
# Enter your environment variables:

# %%
astra_token = getpass.getpass("Astra token:")
astra_endpoint = getpass.getpass("Astra db endpoint:")
openai_key = getpass.getpass("OpenAI Key:")
collection = input("Collection name:")

# %% [markdown]
# ## RAG workflow
#
# With your environment set up, you're ready to create a RAG workflow.

# %% [markdown]
# ### Construct information base
#
# Declare the embeddings model define its required parameters.
# Create your Astra vector database and configure its parameters.

# %%
embedding = OpenAIEmbeddings(openai_api_key=openai_key)
vstore = AstraDB(
        collection_name=collection,
        embedding=embedding,
        token=astra_token,
        api_endpoint=astra_endpoint
    )
print("Astra configured")
# Out:
# Astra configured

# %% [markdown]
# Load a small dataset of quotes with the Python dataset module.

# %%
philo_dataset = load_dataset("datastax/philosopher-quotes")["train"]
print("An example entry:")
print(philo_dataset[16])
# Out:
# An example entry:
# {'author': 'aristotle', 'quote': 'Love well, be loved and do something of value.', 'tags': 'love;ethics'}

# %% [markdown]
# Process metadata and convert:

# %%
docs = []
for entry in philo_dataset:
    metadata = {"author": entry["author"]}
    if entry["tags"]:
        # Add metadata tags to the metadata dictionary
        for tag in entry["tags"].split(";"):
            metadata[tag] = "y"
    # Add a LangChain document with the quote and metadata tags
    doc = Document(page_content=entry["quote"], metadata=metadata)
    docs.append(doc)

# %% [markdown]
# Compute embeddings:

# %%
inserted_ids = vstore.add_documents(docs)
print(f"\nInserted {len(inserted_ids)} documents.")
# Out:
# Inserted 450 documents.

# %% [markdown]
# Confirm your vector store is populated:

# %%
print(vstore.astra_db.collection(collection).find())
# Out:
# {'data': {'documents': [{'_id': '7eba67f9f63c4e88bd00dba7cb3f548a', 'content': 'Those who are not angry at the things they should be angry at are thought to be fools, and so are those who are not angry in the right way, at the right time, or with the right persons.', '$vector': [-0.011329636200437894, -0.015616183476134384, 0.019839506986287815, -0.030777158820591042, -0.03204162854351666, -0.020370584381675286, -0.028399957902159295, -0.026756149311265694, 0.023152415164408385, -0.0033002622142925893, 0.012480302027798896, 0.006249634671863165, -0.011158933151058746, 0.009553058260697427, -0.01031806153968451, 0.011759555198427434, 0.03659371358558429, 0.027565409039868403, 0.018435947959399766, -0.004925103954920049, -0.009451900794622088, 0.02738838324140591, -0.005307605594413591, -0.012334888112107934, -0.022191418771031375, 0.014806923747531677, 0.03403948686869006, -0.020585544811992647, -0.003505738288154289, -0.0425114230226851, 0.013441298421175906, -0.026225071915878223, -0.008301234035938495, -0.006935608709582723, -0.03573387558960521, -0.01617254907388745, 0.004289708650238162, -0.0016596146486946887, 0.028526405433245413, 0.007706934271991854, 0.03727652578310088, -0.026452677844362272, 0.011620464031819816, 0.0018113508478076962, -0.0035468335960588885, 0.021293646143197426, -0.006632136311356708, -0.00888921244778568, -0.030018477359364706, 0.019472811753841333, 0.04746814165434446, -0.007536231222612706, -0.0065183342784372765, -0.019713061317846885, 0.009003014480705113, -0.014844858379386549, -0.007972472504024292, 0.008503548968089171, -0.02584573304791024, 0.006334986196552739, -0.014554030548004629, 0.0020294716049288133, -0.007586809955650376, 0.014225268084767834, 0.004928265329461721, 0.005519404184527986, -0.015021883246526447, -0.00019984526836106645, -0.01723470386466239, -0.00892714614831796, 0.017082967199888086, 0.007169535524504929, -0.0007124488614838564, -0.0026127077221328445, 0.004994650003885155, -0.02599746785003936, -0.02574457465051231, -0.01032438335744526, -0.005105290662262915, -0.0002657359052527866, 0.01736114953310332, -0.010406574438915756, -0.015818499339607654, 0.010950295469824727, -0.010520376471835187, 0.007959827937180199, 0.007099989475539824, 0.00434028738327583, -0.004258097233127928, 0.01481956831437577, -0.022254642536574436, 0.008434003384785362, 0.013618323288315803, 0.01750024069971094, -0.0031753960689692522, 0.022722496166418846, -0.0012028254805001545, -0.0024530685523269547, -0.011917613680962488, -0.03171286421763468, 0.016665691837420046, 0.014035598650783843, -0.03707420898830502, 0.0025431619059983874, -0.005149547111878538, -0.020560253815659277, -0.014971304979150075, -0.010229548640453265, -0.00585448846552553, -0.01449080678246157, -0.011702654181967719, 0.015869077606984028, 0.012726873409565194, -0.04428168100731001, 0.013896506552853632, -0.008579417300476323, 0.013036668556874553, -0.0005863972007073924, -0.014743700913311212, -0.0287034312317079, -0.006306535688322882, 0.013049313123718646, -0.004406672057699264, -0.00012210021908576934, 0.010463475455375472, -0.008060985403255538, -0.022975389365945897, -0.02380993822823679, -0.038920336236639666, -0.00510212975338254, 0.03649255705083155, 0.05508023981236043, -0.007270692990580268, -0.0002438052954576608, -0.002002601783969791, 0.007466685173647601, -0.02532729928804427, -0.001830317930904484, -0.016855363134049225, 0.008111564601954504, -0.01658982443635549, 0.016223129203909007, -0.02703433164448093, -0.010393929872071663, 0.00020191978943679876, 0.0017860614812888614, -0.003069496773912055, 0.014882792079918829, -0.0019267335679979635, -0.01360567872147171, 0.016223129203909007, 0.004571052823656365, 0.02169827600749878, -0.02981616242721403, 0.00942028891185056, 0.03995720003108124, -0.00691031911023324, 0.012556170360186048, -0.0046690493808513285, -0.014478162215617476, 0.023822583726403477, -0.007194824658193115, 0.014794279180687583, 0.010457152706292128, 0.005933517706793057, 0.0095973147 ...

# %% [markdown]
# ### Basic retrieval

# %% [markdown]
# Retrieve context from your vector database, and pass it to OpenAI with a prompt question.

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.schema.output_parser import StrOutputParser
from langchain.schema.runnable import RunnableLambda, RunnablePassthrough

retriever = vstore.as_retriever(search_kwargs={'k': 3})

prompt_template = """
Answer the question based only on the supplied context. If you don't know the answer, say you don't know the answer.
Context: {context}
Question: {question}
Your answer:
"""
prompt = ChatPromptTemplate.from_template(prompt_template)
model = ChatOpenAI(openai_api_key=openai_key)

chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

chain.invoke("In the given context, what subject are philosophers most concerned with?")
# Out:
# 'In the given context, philosophers are most concerned with truth and the unchanging reality that is the object of knowledge.'

# %% [markdown]
# Unsure about this response above? Modify the prompt to return the source documents it used to make its decision.

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.schema.output_parser import StrOutputParser
from langchain.schema.runnable import RunnableMap, RunnableLambda, RunnablePassthrough
from operator import itemgetter

retriever = vstore.as_retriever(search_kwargs={'k': 3})

prompt_template = """
Answer the question based only on the supplied context. If you don't know the answer, say you don't know the answer.
Context: {context}
Question: {question}
Your answer:
"""
prompt = ChatPromptTemplate.from_template(prompt_template)
model = ChatOpenAI(openai_api_key=openai_key)

chain_from_docs = (
        {
        "context": lambda input: docs(input["documents"]),
        "question": itemgetter("question"),
    }
    | prompt
    | model
    | StrOutputParser()
)

chain_with_source = RunnableMap(
    {"documents": retriever, "question": RunnablePassthrough()}
) | {
    "documents": lambda input: [doc.metadata for doc in input["documents"]],
    "answer": chain_from_docs,
}

chain_with_source.invoke("In the given context, what subject are philosophers most concerned with?")
